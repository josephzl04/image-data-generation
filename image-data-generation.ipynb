# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")

# !pip install transformers accelerate pillow safetensors controlnet-aux diffusers
# Out:
# CUDA available: False
# GPU: None
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/drive')

# !find /drive -name "*.ipynb" 2>/dev/null
# Out:
# Mounted at /drive
# /drive/MyDrive/Colab Notebooks/Copy of SearchExercise2.ipynb
# /drive/MyDrive/Colab Notebooks/Copy of SearchExercise6.ipynb
# /drive/MyDrive/Colab Notebooks/Hard copy of SearchExercise5.ipynb
# /drive/MyDrive/Colab Notebooks/Another copy of SearchExercise5.ipynb
# /drive/MyDrive/Colab Notebooks/Copy of SearchExercise5.ipynb
# /drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /drive/MyDrive/Colab Notebooks/En_ZH_language_translation.ipynb
# /drive/MyDrive/Colab Notebooks/blip2test.ipynb
# /drive/MyDrive/Colab Notebooks/image-data-generation.ipynb

# %%
# !git config --global user.email "sc22zzl@leeds.ac.uk"
# !git config --global user.name "josephzl04"

# !git add .
# !git commit -m "Added environment setup and dependencies"
# !git push origin main
